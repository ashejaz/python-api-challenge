# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 615

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    response = requests.get(city_url).json()
    
    # Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve data
        city_weather = response["weather"][0]["description"]

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        city_max_temp = response["main"]["temp_max"]
        city_humidity = response["main"]["humidity"]
        city_clouds = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        city_country = response["sys"]["country"]
        city_date = response["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | urucara
# Processing Record 2 of Set 1 | pokhara
# Processing Record 3 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | mejit
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | margaret river
# Processing Record 9 of Set 1 | walvis bay
# Processing Record 10 of Set 1 | san antonio de pale
# Processing Record 11 of Set 1 | hawaiian paradise park
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | port-aux-francais
# Processing Record 14 of Set 1 | bodo
# Processing Record 15 of Set 1 | invercargill
# Processing Record 16 of Set 1 | balykshi
# Processing Record 17 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 18 of Set 1 | prainha
# Processing Record 19 of Set 1 | asifabad
# Processing Record 20 of Set 1 | portland
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | borisoglebsk
# Processing Record 23 of Set 1 | namibe
# Processing Record 24 of Set 1 | arish
# Processing Record 25 of Set 1 | tolanaro
# Processing Record 26 of Set 1 | lihue
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | enewetak
# Processing Record 29 of Set 1 | kani keli
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | touros
# Processing Record 32 of Set 1 | grytviken
# Processing Record 33 of Set 1 | blackmans bay
# Processing Record 34 of Set 1 | yarega
# Processing Record 35 of Set 1 | edinburgh of the seven seas
# Processing Record 36 of Set 1 | banda aceh
# Processing Record 37 of Set 1 | klyuchi
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | fort mcmurray
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | ilha de mocambique
# Processing Record 42 of Set 1 | luena
# Processing Record 43 of Set 1 | nova sintra
# Processing Record 44 of Set 1 | san patricio
# Processing Record 45 of Set 1 | iskateley
# Processing Record 46 of Set 1 | axim
# Processing Record 47 of Set 1 | kingston
# Processing Record 48 of Set 1 | whitehorse
# Processing Record 49 of Set 1 | auki
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 0 of Set 2 | waitangi
# Processing Record 1 of Set 2 | badger
# Processing Record 2 of Set 2 | codrington
# Processing Record 3 of Set 2 | lingyuan
# Processing Record 4 of Set 2 | campos belos
# Processing Record 5 of Set 2 | stanley
# Processing Record 6 of Set 2 | holualoa
# Processing Record 7 of Set 2 | tazacorte
# Processing Record 8 of Set 2 | la ronge
# Processing Record 9 of Set 2 | bilibino
# Processing Record 10 of Set 2 | jinghong
# Processing Record 11 of Set 2 | vorgashor
# Processing Record 12 of Set 2 | yuzhno-kurilsk
# Processing Record 13 of Set 2 | dondo
# Processing Record 14 of Set 2 | ust-nera
# Processing Record 15 of Set 2 | fort bragg
# Processing Record 16 of Set 2 | puerto armuelles
# Processing Record 17 of Set 2 | tezu
# Processing Record 18 of Set 2 | sisimiut
# Processing Record 19 of Set 2 | toliara
# Processing Record 20 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 21 of Set 2 | taiyuan
# Processing Record 22 of Set 2 | papatowai
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | tsiombe
# Processing Record 26 of Set 2 | tucurui
# Processing Record 27 of Set 2 | i-n-salah
# Processing Record 28 of Set 2 | college
# Processing Record 29 of Set 2 | illizi
# Processing Record 30 of Set 2 | olonkinbyen
# Processing Record 31 of Set 2 | flying fish cove
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | utrik
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 38 of Set 2 | rio grande
# Processing Record 39 of Set 2 | piti village
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | puerto natales
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | howrah
# Processing Record 44 of Set 2 | kataba
# Processing Record 45 of Set 2 | kaimganj
# Processing Record 46 of Set 2 | karasuk
# Processing Record 47 of Set 2 | puerto baquerizo moreno
# Processing Record 48 of Set 2 | carbondale
# Processing Record 49 of Set 2 | west island
# Processing Record 0 of Set 3 | cabo san lucas
# Processing Record 1 of Set 3 | acarau
# Processing Record 2 of Set 3 | fale old settlement
# Processing Record 3 of Set 3 | ciudad insurgentes
# Processing Record 4 of Set 3 | nuuk
# Processing Record 5 of Set 3 | kavaratti
# Processing Record 6 of Set 3 | leava
# Processing Record 7 of Set 3 | quellon
# Processing Record 8 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 3 | sishilichengzi
# City not found. Skipping...
# Processing Record 10 of Set 3 | kudahuvadhoo
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | marsabit
# Processing Record 13 of Set 3 | opuwo
# Processing Record 14 of Set 3 | conduaga
# Processing Record 15 of Set 3 | uturoa
# Processing Record 16 of Set 3 | belle fourche
# Processing Record 17 of Set 3 | taulaga
# Processing Record 18 of Set 3 | yigo village
# Processing Record 19 of Set 3 | aykhal
# Processing Record 20 of Set 3 | micheweni
# Processing Record 21 of Set 3 | finote selam
# Processing Record 22 of Set 3 | pacific grove
# Processing Record 23 of Set 3 | praia
# Processing Record 24 of Set 3 | hamilton
# Processing Record 25 of Set 3 | fort morgan
# Processing Record 26 of Set 3 | kingscliff
# Processing Record 27 of Set 3 | suva
# Processing Record 28 of Set 3 | scarborough
# Processing Record 29 of Set 3 | nyurba
# Processing Record 30 of Set 3 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 31 of Set 3 | wailua homesteads
# Processing Record 32 of Set 3 | pushchino
# Processing Record 33 of Set 3 | strelka
# Processing Record 34 of Set 3 | copalnic manastur
# Processing Record 35 of Set 3 | namtsy
# Processing Record 36 of Set 3 | kavieng
# Processing Record 37 of Set 3 | bandar
# Processing Record 38 of Set 3 | vila velha
# Processing Record 39 of Set 3 | mukhorshibir'
# City not found. Skipping...
# Processing Record 40 of Set 3 | palpala
# Processing Record 41 of Set 3 | talnakh
# Processing Record 42 of Set 3 | garachico
# Processing Record 43 of Set 3 | paoua
# Processing Record 44 of Set 3 | anadyr
# Processing Record 45 of Set 3 | kuanda
# Processing Record 46 of Set 3 | shakawe
# Processing Record 47 of Set 3 | vorkuta
# Processing Record 48 of Set 3 | tazovsky
# Processing Record 49 of Set 3 | punta arenas
# Processing Record 0 of Set 4 | murun-kuren
# Processing Record 1 of Set 4 | markovo
# Processing Record 2 of Set 4 | port lincoln
# Processing Record 3 of Set 4 | kamogawa
# Processing Record 4 of Set 4 | isafjordur
# Processing Record 5 of Set 4 | st. john's
# Processing Record 6 of Set 4 | mahabe
# City not found. Skipping...
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | kapoeta
# Processing Record 9 of Set 4 | marijampole
# Processing Record 10 of Set 4 | mount pearl
# Processing Record 11 of Set 4 | fortuna
# Processing Record 12 of Set 4 | lobujya
# Processing Record 13 of Set 4 | kerikeri
# Processing Record 14 of Set 4 | mujiayingzi
# Processing Record 15 of Set 4 | nyala
# Processing Record 16 of Set 4 | arawa
# Processing Record 17 of Set 4 | chaklasi
# Processing Record 18 of Set 4 | pleiku
# Processing Record 19 of Set 4 | khorugh
# Processing Record 20 of Set 4 | daru
# Processing Record 21 of Set 4 | salinopolis
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | galliano
# Processing Record 24 of Set 4 | natchez
# Processing Record 25 of Set 4 | rongelap
# Processing Record 26 of Set 4 | tamiahua
# Processing Record 27 of Set 4 | medicine hat
# Processing Record 28 of Set 4 | timbuktu
# Processing Record 29 of Set 4 | buala
# Processing Record 30 of Set 4 | yurga
# Processing Record 31 of Set 4 | santana
# Processing Record 32 of Set 4 | noosa heads
# Processing Record 33 of Set 4 | ancud
# Processing Record 34 of Set 4 | tanrake village
# City not found. Skipping...
# Processing Record 35 of Set 4 | kijang
# Processing Record 36 of Set 4 | waingapu
# Processing Record 37 of Set 4 | lebu
# Processing Record 38 of Set 4 | port mathurin
# Processing Record 39 of Set 4 | polyarnyy
# Processing Record 40 of Set 4 | dingli
# Processing Record 41 of Set 4 | atafu village
# Processing Record 42 of Set 4 | dudinka
# Processing Record 43 of Set 4 | zheleznogorsk-ilimskiy
# Processing Record 44 of Set 4 | port shepstone
# Processing Record 45 of Set 4 | salalah
# Processing Record 46 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 47 of Set 4 | aomori
# Processing Record 48 of Set 4 | sao vicente
# Processing Record 49 of Set 4 | al azraq ash shamali
# City not found. Skipping...
# Processing Record 0 of Set 5 | hirara
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | alexandria
# Processing Record 3 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 4 of Set 5 | koryazhma
# Processing Record 5 of Set 5 | mata-utu
# Processing Record 6 of Set 5 | ceyhan
# Processing Record 7 of Set 5 | prince rupert
# Processing Record 8 of Set 5 | kamaishi
# Processing Record 9 of Set 5 | mugia
# Processing Record 10 of Set 5 | nikolayevsk-on-amure
# Processing Record 11 of Set 5 | untergriesbach
# Processing Record 12 of Set 5 | udachny
# Processing Record 13 of Set 5 | okha
# Processing Record 14 of Set 5 | bardai
# Processing Record 15 of Set 5 | kanggye
# Processing Record 16 of Set 5 | verkhnevilyuysk
# Processing Record 17 of Set 5 | ulan bator
# Processing Record 18 of Set 5 | ciudad bolivar
# Processing Record 19 of Set 5 | toulepleu guere
# Processing Record 20 of Set 5 | saint-pierre
# Processing Record 21 of Set 5 | kapuskasing
# Processing Record 22 of Set 5 | ribeira brava
# Processing Record 23 of Set 5 | grand falls-windsor
# Processing Record 24 of Set 5 | miragoane
# Processing Record 25 of Set 5 | afaahiti
# Processing Record 26 of Set 5 | suntar
# Processing Record 27 of Set 5 | una
# Processing Record 28 of Set 5 | avarua
# Processing Record 29 of Set 5 | plymouth
# Processing Record 30 of Set 5 | ilhabela
# Processing Record 31 of Set 5 | aasiaat
# Processing Record 32 of Set 5 | chonchi
# Processing Record 33 of Set 5 | keflavik
# Processing Record 34 of Set 5 | tindouf
# Processing Record 35 of Set 5 | yilan
# Processing Record 36 of Set 5 | totness
# Processing Record 37 of Set 5 | yesilova
# Processing Record 38 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 39 of Set 5 | kshenskiy
# Processing Record 40 of Set 5 | vilyuchinsk
# Processing Record 41 of Set 5 | urangan
# Processing Record 42 of Set 5 | novo oriente
# Processing Record 43 of Set 5 | colonia
# Processing Record 44 of Set 5 | palikir - national government center
# Processing Record 45 of Set 5 | viborg
# Processing Record 46 of Set 5 | taneytown
# Processing Record 47 of Set 5 | sinabang
# Processing Record 48 of Set 5 | geraldton
# Processing Record 49 of Set 5 | greymouth
# Processing Record 0 of Set 6 | kupang
# Processing Record 1 of Set 6 | porto novo
# Processing Record 2 of Set 6 | emmett
# Processing Record 3 of Set 6 | tofol
# Processing Record 4 of Set 6 | bel ombre
# Processing Record 5 of Set 6 | santa ana
# Processing Record 6 of Set 6 | nafpaktos
# Processing Record 7 of Set 6 | sao jose da coroa grande
# Processing Record 8 of Set 6 | khanty-mansiysk
# Processing Record 9 of Set 6 | estevan
# Processing Record 10 of Set 6 | igarka
# Processing Record 11 of Set 6 | chul'man
# Processing Record 12 of Set 6 | balkh
# Processing Record 13 of Set 6 | praia da vitoria
# Processing Record 14 of Set 6 | panama city beach
# Processing Record 15 of Set 6 | nouadhibou
# Processing Record 16 of Set 6 | turkmenbasy
# Processing Record 17 of Set 6 | tallulah
# Processing Record 18 of Set 6 | murzuq
# Processing Record 19 of Set 6 | congonhas
# Processing Record 20 of Set 6 | bichura
# Processing Record 21 of Set 6 | barabai
# Processing Record 22 of Set 6 | sao mateus
# Processing Record 23 of Set 6 | wynyard
# Processing Record 24 of Set 6 | zanjan
# Processing Record 25 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 26 of Set 6 | newman
# Processing Record 27 of Set 6 | machico
# Processing Record 28 of Set 6 | la'ie
# Processing Record 29 of Set 6 | gamba
# Processing Record 30 of Set 6 | betio village
# Processing Record 31 of Set 6 | laojunmiao
# Processing Record 32 of Set 6 | carbonear
# Processing Record 33 of Set 6 | antalaha
# Processing Record 34 of Set 6 | ghat
# Processing Record 35 of Set 6 | yuza
# Processing Record 36 of Set 6 | babaeski
# Processing Record 37 of Set 6 | thornton
# Processing Record 38 of Set 6 | fisterra
# Processing Record 39 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 40 of Set 6 | zelenoborskiy
# Processing Record 41 of Set 6 | viedma
# Processing Record 42 of Set 6 | saudarkrokur
# Processing Record 43 of Set 6 | cidreira
# Processing Record 44 of Set 6 | port alfred
# Processing Record 45 of Set 6 | sundargarh
# Processing Record 46 of Set 6 | kisangani
# Processing Record 47 of Set 6 | kapa'a
# Processing Record 48 of Set 6 | hong kong
# Processing Record 49 of Set 6 | mandalgovi
# Processing Record 0 of Set 7 | kununurra
# Processing Record 1 of Set 7 | dongola
# Processing Record 2 of Set 7 | palasa
# Processing Record 3 of Set 7 | cukai
# Processing Record 4 of Set 7 | berezovo
# Processing Record 5 of Set 7 | kyren
# Processing Record 6 of Set 7 | perelyub
# Processing Record 7 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 8 of Set 7 | calp
# Processing Record 9 of Set 7 | stjordalshalsen
# Processing Record 10 of Set 7 | upington
# Processing Record 11 of Set 7 | laayoune plage
# City not found. Skipping...
# Processing Record 12 of Set 7 | juan griego
# Processing Record 13 of Set 7 | kramfors
# Processing Record 14 of Set 7 | flin flon
# Processing Record 15 of Set 7 | teruel
# Processing Record 16 of Set 7 | moriki
# Processing Record 17 of Set 7 | xai-xai
# Processing Record 18 of Set 7 | andergrove
# Processing Record 19 of Set 7 | hithadhoo
# Processing Record 20 of Set 7 | omdurman
# Processing Record 21 of Set 7 | cortez
# Processing Record 22 of Set 7 | zykovo
# Processing Record 23 of Set 7 | hami
# Processing Record 24 of Set 7 | camana
# Processing Record 25 of Set 7 | richards bay
# Processing Record 26 of Set 7 | richfield
# Processing Record 27 of Set 7 | susuman
# Processing Record 28 of Set 7 | okhotsk
# Processing Record 29 of Set 7 | obudu
# Processing Record 30 of Set 7 | castillos
# Processing Record 31 of Set 7 | la passe
# Processing Record 32 of Set 7 | lompoc
# Processing Record 33 of Set 7 | charlottetown
# Processing Record 34 of Set 7 | tahe
# Processing Record 35 of Set 7 | barclayville
# Processing Record 36 of Set 7 | kirensk
# Processing Record 37 of Set 7 | rapla
# Processing Record 38 of Set 7 | lata
# Processing Record 39 of Set 7 | khovd
# Processing Record 40 of Set 7 | ciutadella
# Processing Record 41 of Set 7 | mukah
# City not found. Skipping...
# Processing Record 42 of Set 7 | papao
# Processing Record 43 of Set 7 | tefe
# Processing Record 44 of Set 7 | bouafle
# Processing Record 45 of Set 7 | grajau
# Processing Record 46 of Set 7 | port elizabeth
# Processing Record 47 of Set 7 | lander
# Processing Record 48 of Set 7 | kaffrine
# Processing Record 49 of Set 7 | lincoln
# Processing Record 0 of Set 8 | chios
# Processing Record 1 of Set 8 | sitka
# Processing Record 2 of Set 8 | abaete
# Processing Record 3 of Set 8 | verkhnyaya sinyachikha
# Processing Record 4 of Set 8 | itupiranga
# Processing Record 5 of Set 8 | ilulissat
# Processing Record 6 of Set 8 | constantia
# Processing Record 7 of Set 8 | prieska
# Processing Record 8 of Set 8 | minas de marcona
# Processing Record 9 of Set 8 | general cabrera
# Processing Record 10 of Set 8 | hiratacho
# Processing Record 11 of Set 8 | makhambet
# Processing Record 12 of Set 8 | kailua-kona
# Processing Record 13 of Set 8 | alto barinas
# Processing Record 14 of Set 8 | sinjai
# Processing Record 15 of Set 8 | tayoltita
# Processing Record 16 of Set 8 | khash
# Processing Record 17 of Set 8 | dalandzadgad
# Processing Record 18 of Set 8 | nuku'alofa
# Processing Record 19 of Set 8 | bogale
# Processing Record 20 of Set 8 | powell river
# Processing Record 21 of Set 8 | turpan
# Processing Record 22 of Set 8 | qaqortoq
# Processing Record 23 of Set 8 | alta
# Processing Record 24 of Set 8 | comodoro rivadavia
# Processing Record 25 of Set 8 | namdrik
# Processing Record 26 of Set 8 | rumbek
# Processing Record 27 of Set 8 | mantua
# Processing Record 28 of Set 8 | brisas de zicatela
# Processing Record 29 of Set 8 | tromso
# Processing Record 30 of Set 8 | baise city
# Processing Record 31 of Set 8 | naifaru
# Processing Record 32 of Set 8 | peruibe
# Processing Record 33 of Set 8 | marion
# Processing Record 34 of Set 8 | orkney
# Processing Record 35 of Set 8 | latakia
# Processing Record 36 of Set 8 | crucecita
# Processing Record 37 of Set 8 | alice springs
# Processing Record 38 of Set 8 | coro
# Processing Record 39 of Set 8 | rio verde de mato grosso
# Processing Record 40 of Set 8 | kultali
# City not found. Skipping...
# Processing Record 41 of Set 8 | sao geraldo do araguaia
# Processing Record 42 of Set 8 | redencao
# Processing Record 43 of Set 8 | essaouira
# Processing Record 44 of Set 8 | malango
# Processing Record 45 of Set 8 | ar rutbah
# Processing Record 46 of Set 8 | muzayri'
# City not found. Skipping...
# Processing Record 47 of Set 8 | saldanha
# Processing Record 48 of Set 8 | fada
# Processing Record 49 of Set 8 | porbandar
# Processing Record 0 of Set 9 | tura
# Processing Record 1 of Set 9 | lambarene
# Processing Record 2 of Set 9 | notodden
# Processing Record 3 of Set 9 | praya
# Processing Record 4 of Set 9 | muscat
# Processing Record 5 of Set 9 | happy valley-goose bay
# Processing Record 6 of Set 9 | itoman
# Processing Record 7 of Set 9 | caconda
# Processing Record 8 of Set 9 | al hudaydah
# Processing Record 9 of Set 9 | peace river
# Processing Record 10 of Set 9 | aberglasslyn
# Processing Record 11 of Set 9 | zaterechnyy
# Processing Record 12 of Set 9 | weno
# Processing Record 13 of Set 9 | asau village
# City not found. Skipping...
# Processing Record 14 of Set 9 | ceylanpinar
# Processing Record 15 of Set 9 | robore
# Processing Record 16 of Set 9 | pago pago
# Processing Record 17 of Set 9 | ouadda
# Processing Record 18 of Set 9 | fort st. john
# Processing Record 19 of Set 9 | batticaloa
# Processing Record 20 of Set 9 | barkly west
# Processing Record 21 of Set 9 | shingu
# Processing Record 22 of Set 9 | vila franca do campo
# Processing Record 23 of Set 9 | tembisa
# Processing Record 24 of Set 9 | nemuro
# Processing Record 25 of Set 9 | kawthoung
# City not found. Skipping...
# Processing Record 26 of Set 9 | puerto cabezas
# Processing Record 27 of Set 9 | cortland
# Processing Record 28 of Set 9 | yeniseysk
# Processing Record 29 of Set 9 | paradip garh
# Processing Record 30 of Set 9 | catarman
# Processing Record 31 of Set 9 | greenville
# Processing Record 32 of Set 9 | taltal
# Processing Record 33 of Set 9 | zakynthos
# Processing Record 34 of Set 9 | north ward
# Processing Record 35 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 9 | north bend
# Processing Record 37 of Set 9 | jaisalmer
# Processing Record 38 of Set 9 | tchibanga
# Processing Record 39 of Set 9 | zabol
# Processing Record 40 of Set 9 | kovdor
# Processing Record 41 of Set 9 | laguna
# Processing Record 42 of Set 9 | thurso
# Processing Record 43 of Set 9 | ixtapa
# Processing Record 44 of Set 9 | conception bay south
# Processing Record 45 of Set 9 | coahuayana de hidalgo
# Processing Record 46 of Set 9 | gadzhiyevo
# Processing Record 47 of Set 9 | krasnozerskoye
# Processing Record 48 of Set 9 | miri
# Processing Record 49 of Set 9 | gaiman
# Processing Record 0 of Set 10 | durban
# Processing Record 1 of Set 10 | margate
# Processing Record 2 of Set 10 | jiaojiang
# Processing Record 3 of Set 10 | oranjemund
# Processing Record 4 of Set 10 | as sulayyil
# Processing Record 5 of Set 10 | east london
# Processing Record 6 of Set 10 | broome
# Processing Record 7 of Set 10 | hobyo
# Processing Record 8 of Set 10 | yangor
# City not found. Skipping...
# Processing Record 9 of Set 10 | awjilah
# Processing Record 10 of Set 10 | antsiranana
# Processing Record 11 of Set 10 | formosa
# Processing Record 12 of Set 10 | trondheim
# Processing Record 13 of Set 10 | astrakhan
# Processing Record 14 of Set 10 | salym
# Processing Record 15 of Set 10 | nar'yan-mar
# Processing Record 16 of Set 10 | turtas
# Processing Record 17 of Set 10 | kargasok
# Processing Record 18 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 19 of Set 10 | labasa
# Processing Record 20 of Set 10 | kralendijk
# Processing Record 21 of Set 10 | taroa
# Processing Record 22 of Set 10 | corner brook
# Processing Record 23 of Set 10 | new norfolk
# Processing Record 24 of Set 10 | zalesovo
# Processing Record 25 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 26 of Set 10 | fort wellington
# Processing Record 27 of Set 10 | ulladulla
# Processing Record 28 of Set 10 | puerto san jose
# Processing Record 29 of Set 10 | kyakhta
# Processing Record 30 of Set 10 | plastun
# Processing Record 31 of Set 10 | lamu
# Processing Record 32 of Set 10 | chepen
# Processing Record 33 of Set 10 | floro
# Processing Record 34 of Set 10 | callao
# Processing Record 35 of Set 10 | chalastra
# Processing Record 36 of Set 10 | ketchikan
# Processing Record 37 of Set 10 | kaspiyskiy
# Processing Record 38 of Set 10 | kourou
# Processing Record 39 of Set 10 | senanga
# Processing Record 40 of Set 10 | chekhov
# Processing Record 41 of Set 10 | balqash
# Processing Record 42 of Set 10 | saint croix
# Processing Record 43 of Set 10 | imbituba
# Processing Record 44 of Set 10 | sant lluis
# Processing Record 45 of Set 10 | rocha
# Processing Record 46 of Set 10 | itamaraca
# Processing Record 47 of Set 10 | al ghayzah
# Processing Record 48 of Set 10 | luebo
# Processing Record 49 of Set 10 | naantali
# Processing Record 0 of Set 11 | debre tabor
# Processing Record 1 of Set 11 | khandyga
# Processing Record 2 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 11 | tarawa
# Processing Record 4 of Set 11 | tarko-sale
# Processing Record 5 of Set 11 | novodvinsk
# Processing Record 6 of Set 11 | san pedro pochutla
# Processing Record 7 of Set 11 | pajapan
# Processing Record 8 of Set 11 | ola
# Processing Record 9 of Set 11 | bumba
# Processing Record 10 of Set 11 | caleta de carquin
# Processing Record 11 of Set 11 | taoudenni
# Processing Record 12 of Set 11 | saint-joseph
# Processing Record 13 of Set 11 | prien
# Processing Record 14 of Set 11 | xining
# Processing Record 15 of Set 11 | inhambane
# Processing Record 16 of Set 11 | chabahar
# Processing Record 17 of Set 11 | torquay
# Processing Record 18 of Set 11 | lazaro cardenas
# Processing Record 19 of Set 11 | salahonda
# Processing Record 20 of Set 11 | bakchar
# Processing Record 21 of Set 11 | stanthorpe
# Processing Record 22 of Set 11 | kitimat
# Processing Record 23 of Set 11 | dahlonega
# Processing Record 24 of Set 11 | wangjing
# Processing Record 25 of Set 11 | nieuw amsterdam
# Processing Record 26 of Set 11 | sucre
# Processing Record 27 of Set 11 | manismata
# Processing Record 28 of Set 11 | 'izbat al burj
# City not found. Skipping...
# Processing Record 29 of Set 11 | bata
# Processing Record 30 of Set 11 | trubchevsk
# Processing Record 31 of Set 11 | howard springs
# Processing Record 32 of Set 11 | chu
# Processing Record 33 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 34 of Set 11 | serhiyivka
# Processing Record 35 of Set 11 | hovd
# Processing Record 36 of Set 11 | gao
# Processing Record 37 of Set 11 | fiambala
# Processing Record 38 of Set 11 | kayyerkan
# Processing Record 39 of Set 11 | santa elena de uairen
# Processing Record 40 of Set 11 | saint-philippe
# Processing Record 41 of Set 11 | port-vila
# Processing Record 42 of Set 11 | severo-yeniseyskiy
# Processing Record 43 of Set 11 | claveria
# Processing Record 44 of Set 11 | male
# Processing Record 45 of Set 11 | amga
# Processing Record 46 of Set 11 | zaozersk
# Processing Record 47 of Set 11 | general roca
# Processing Record 48 of Set 11 | phang nga
# Processing Record 49 of Set 11 | soc trang
# Processing Record 0 of Set 12 | toamasina
# Processing Record 1 of Set 12 | tamanrasset
# Processing Record 2 of Set 12 | el dorado
# Processing Record 3 of Set 12 | woodlake
# Processing Record 4 of Set 12 | westport
# Processing Record 5 of Set 12 | sao tome
# Processing Record 6 of Set 12 | san juan de miraflores
# Processing Record 7 of Set 12 | lerwick
# Processing Record 8 of Set 12 | khon buri
# Processing Record 9 of Set 12 | carutapera
# Processing Record 10 of Set 12 | kaa-khem
# Processing Record 11 of Set 12 | pul-e khumri
# Processing Record 12 of Set 12 | beyneu
# Processing Record 13 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 14 of Set 12 | teluk nibung
# Processing Record 15 of Set 12 | krasnoufimsk
# Processing Record 16 of Set 12 | verkhotur'ye
# Processing Record 17 of Set 12 | elmendorf air force base
# City not found. Skipping...
# Processing Record 18 of Set 12 | ankazoabo
# Processing Record 19 of Set 12 | mahajanga
# Processing Record 20 of Set 12 | bargara
# City not found. Skipping...
# Processing Record 21 of Set 12 | lhasa
# Processing Record 22 of Set 12 | yarumal
# Processing Record 23 of Set 12 | bubaque
# Processing Record 24 of Set 12 | oriximina
# Processing Record 25 of Set 12 | bageshwar
# Processing Record 26 of Set 12 | muroto-misakicho
# Processing Record 27 of Set 12 | oroqen zizhiqi
# Processing Record 28 of Set 12 | rodriguez
# Processing Record 29 of Set 12 | san isidro
# Processing Record 30 of Set 12 | el fasher
# Processing Record 31 of Set 12 | chita
# Processing Record 32 of Set 12 | iquique
# Processing Record 33 of Set 12 | hadibu
# Processing Record 34 of Set 12 | tshela
# Processing Record 35 of Set 12 | qarauyl
# Processing Record 36 of Set 12 | muisne
# Processing Record 37 of Set 12 | ulsteinvik
# Processing Record 38 of Set 12 | palmer
# Processing Record 39 of Set 12 | champerico
# Processing Record 40 of Set 12 | olyokminsk
# Processing Record 41 of Set 12 | myeik
# Processing Record 42 of Set 12 | konarka
# Processing Record 43 of Set 12 | concepcion del oro
# Processing Record 44 of Set 12 | ishimbay
# Processing Record 45 of Set 12 | vadso
# Processing Record 46 of Set 12 | oak bay
# Processing Record 47 of Set 12 | banfora
# Processing Record 48 of Set 12 | neiafu
# Processing Record 49 of Set 12 | kayangel
# Processing Record 0 of Set 13 | negotin
# Processing Record 1 of Set 13 | el calafate
# Processing Record 2 of Set 13 | renqiu
# Processing Record 3 of Set 13 | chipinge
# Processing Record 4 of Set 13 | kukmor
# Processing Record 5 of Set 13 | hultsfred
# Processing Record 6 of Set 13 | acatlan de osorio
# Processing Record 7 of Set 13 | ibi
# Processing Record 8 of Set 13 | tual
# Processing Record 9 of Set 13 | medina
# Processing Record 10 of Set 13 | tinajo
# Processing Record 11 of Set 13 | mascara
# Processing Record 12 of Set 13 | orsa
# Processing Record 13 of Set 13 | san jose del guaviare
# Processing Record 14 of Set 13 | ataq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          583
# Lat           583
# Lng           583
# Max Temp      583
# Humidity      583
# Cloudiness    583
# Wind Speed    583
# Country       583
# Date          583
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       urucara  -2.5364  -57.7600     33.48        44           4
# 1       pokhara  28.2333   83.9833     24.91        36          36
# 2  longyearbyen  78.2186   15.6401      1.91        60          20
# 3         tiksi  71.6872  128.8694      2.29        63          80
# 4         mejit  10.2753  170.8646     27.50        77         100
#
#    Wind Speed Country        Date
# 0        2.67      BR  1685637000
# 1        3.17      NP  1685637000
# 2        4.63      SJ  1685636892
# 3        2.99      RU  1685637001
# 4        6.76      MH  1685637001

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             urucara  -2.5364  -57.7600     33.48        44           4
# 1             pokhara  28.2333   83.9833     24.91        36          36
# 2        longyearbyen  78.2186   15.6401      1.91        60          20
# 3               tiksi  71.6872  128.8694      2.29        63          80
# 4               mejit  10.2753  170.8646     27.50        77         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.67      BR  1685637000
# 1              3.17      NP  1685637000
# 2              4.63      SJ  1685636892
# 3              2.99      RU  1685637001
# 4              6.76      MH  1685637001

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (01/06/2023)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (01/06/2023)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (01/06/2023)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed (01/06/2023)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values, x_label, y_label, title, label_position):
    
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.annotate(line_eq,(label_position),fontsize=15,color="red")
    plt.show()
    print(f"The r-value is {st.pearsonr(x_values, y_values)[0]}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                       pokhara  28.2333   83.9833     24.91        36
# 2                  longyearbyen  78.2186   15.6401      1.91        60
# 3                         tiksi  71.6872  128.8694      2.29        63
# 4                         mejit  10.2753  170.8646     27.50        77
# 9        hawaiian paradise park  19.5933 -154.9731     21.69        97
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                36        3.17      NP  1685637000
# 2                20        4.63      SJ  1685636892
# 3                80        2.99      RU  1685637001
# 4               100        6.76      MH  1685637001
# 9                 0        2.57      US  1685637002

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                    urucara  -2.5364  -57.7600     33.48        44
# 5                  adamstown -25.0660 -130.1015     24.30        86
# 6             margaret river -33.9500  115.0667     12.87        70
# 7                 walvis bay -22.9575   14.5053     14.49        76
# 8        san antonio de pale  -1.4014    5.6325     26.53        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 4        2.67      BR  1685637000
# 5               100       11.98      PN  1685637001
# 6                88        3.55      AU  1685637001
# 7                 6        1.32     NaN  1685637001
# 8                69        3.62      GQ  1685637001

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Latitude", "Max Temperature (C)", 
                  "Northern Hemisphere Latitude vs Max Temperature", (2, 2))
# Out:
# The r-value is -0.7590191639317609

# %%
# Linear regression on Southern Hemisphere
linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Latitude", "Max Temperature (C)", 
                  "Southern Hemisphere Latitude vs Max Temperature", (-30, 3))
# Out:
# The r-value is 0.8459761894781586

# %% [markdown]
# **Discussion about the linear relationship:** From these plots we can see that Latitude and Temperature have a strong negative correlation in the Northern Hemisphere and a strong positive correlation in the Southern Hemisphere. Not only is there correlation between the variables, we can see that temperatures are highest when the Latitude value is close to 0. This supports the conclusion that global temperatures are highest around the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Latitude", "Humidity (%)", 
                  "Northern Hemisphere Latitude vs Humidity", (46, 10))
# Out:
# The r-value is 0.028166202973567697

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Latitude", "Humidity (%)", 
                  "Southern Hemisphere Latitude vs Humidity", (-54, 20))
# Out:
# The r-value is 0.01436342896435314

# %% [markdown]
# **Discussion about the linear relationship:** From these plots we can see that irrespective of hemisphere, humidity does not seem to have any significant correlation with latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Latitude", "Cloudiness (%)", 
                  "Northern Hemisphere Latitude vs Cloudiness", (0, 30))
# Out:
# The r-value is -0.027739352133511242

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Latitude", "Cloudiness (%)", 
                  "Southern Hemisphere Latitude vs Cloudiness", (-55, 22))
# Out:
# The r-value is -0.048735706293638076

# %% [markdown]
# **Discussion about the linear relationship:** From these plots we can see that irrespective of hemisphere, cloudiness does not seem to have any significant correlation with latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Latitude", "Wind Speed (m/s)", 
                  "Northern Hemisphere Latitude vs Wind Speed", (34, 14))
# Out:
# The r-value is 0.005341689435833623

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Latitude", "Wind Speed (m/s)", 
                  "Southern Hemisphere Latitude vs Wind Speed", (-34, 14))
# Out:
# The r-value is -0.15376089403917018

# %% [markdown]
# **Discussion about the linear relationship:** From these plots we can see that irrespective of hemisphere, wind speed does not seem to have any significant correlation with latitude.
